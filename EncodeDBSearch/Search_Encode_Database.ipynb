# %% [markdown]
# <h2> Jupyter notebook to search the Encode database </h2>

# %% [markdown]
# Import the class ConnectToEncode API (+ requests and json modules)

# %%
from connectEncodeAPI import ConnectToEncodeAPI

# %% [markdown]
# <h3> Create the connection object </h3>

# %%
database = ConnectToEncodeAPI()

# %% [markdown]
# Check the connection to the database

# %%
database.check_database_connection()
print("Status code of connection is %s" % database.response_status_code)
# Out:
# Status code of connection is 200

# %% [markdown]
# <h3> Perform a custom search </h3>

# %% [markdown]
# The Encode API allows for six types of queries:
# <ol>
#     <li> General key word search </li>
#     <li> Search for a biosample by ID </li>
#     <li> Search for a file based on an md5 code </li>
#     <li> Search for an experiment based on an experiment accession number </li>
#     <li> Search for all fastq files belonging to one experiment </li>
#     <li> Search all replicates for experiment </li>
# </ol>

# %% [markdown]
# <b> Perform search on a general key word </b>

# %%
search_request='Liver cancer'

# %%
database.general_search_on_key_word(key_word=search_request)

# %%
print("Number of results based on key word %s: " % database.response_search.json()['total'])
# Out:
# Number of results based on key word 9961:

# %% [markdown]
# To Fix: you can only see the first 25 [index 0 -24] results in from the API request

# %%
study_number = 0  # remember python indexing starts at 0, max =24

# %%
database.response_search.json()['@graph'][11]
# Out:
# {'@id': '/publications/c1e30870-7ad5-4796-8a6d-5652c0947122/',
#  '@type': ['Publication', 'Item'],
#  'abstract': 'Serum gamma-glutamyl transferase (GGT) activity is a marker of liver disease which is also prospectively associated with the risk of all-cause mortality, cardiovascular disease, type 2 diabetes and cancers. We have discovered novel loci affecting GGT in a genome-wide association study (rs1497406 in an intergenic region of chromosome 1, P = 3.9 x 10(-8); rs944002 in C14orf73 on chromosome 14, P = 4.7 x 10(-13); rs340005 in RORA on chromosome 15, P = 2.4 x 10(-8)), and a highly significant heterogeneity between adult and adolescent results at the GGT1 locus on chromosome 22 (maximum P(HET) = 5.6 x 10(-12) at rs6519520). Pathway analysis of significant and suggestive single-nucleotide polymorphism associations showed significant overlap between genes affecting GGT and those affecting common metabolic and inflammatory diseases, and identified the hepatic nuclear factor (HNF) family as controllers of a network of genes affecting GGT. Our results reinforce the disease associations of GGT and demonstrate that control by the GGT1 locus varies with age.',
#  'authors': 'Middelberg RP, Benyamin B, de Moor MH, Warrington NM, Gordon S, Henders AK, Medland SE, Nyholt DR, de Geus EJ, Hottenga JJ, Willemsen G, Beilin LJ, Mori TA, Wright MJ, Heath AC, Madden PA, Boomsma DI, Pennell CE, Montgomery GW, Martin NG, Whitfield JB',
#  'award': '/awards/ENCODE/',
#  'categories': ['human disease'],
#  'data_used': 'ENCODE TF ChIP, histone modification ChIP, described in discussion',
#  'date_created': '2014-08-13T01:27:03.621323+00:00',
#  'date_published': '2012 Jan 15',
#  'documents': [],
#  'identifiers': ['PMCID:PMC3276286', 'PMID:22010049'],
#  'issue': '2',
#  'journal': 'Human molecular genetics',
#  'lab': '/labs/encode-consortium/',
#  'page': '446-55',
#  'publication_data': [],
#  'publication_year': 2012,
#  'published_by': ['community'],
#  'schema_version': '9',
#  'status': 'released',
#  'submitted_by': '/users/ce2bde01-07ec-4b8a-b179-554ef95b71dd/',
#  'supplementary_data': [],
#  'title': 'Loci affecting gamma-glutamyl transferase in adults and adolescents show age x SNP interaction and cardiometabolic disease associations.',
#  'uuid': 'c1e30870-7ad5-4796-8a6d-5652c0947122',
#  'volume': '21'}

# %% [markdown]
# <b> Perform search on biosample ID </b>

# %%
biosample_ID = "ENCBS000AAA"

# %%
database.search_for_biosample(accession_number=biosample_ID)

# %%
database.biosample_response.json()
# Out:
# {'accession': 'ENCBS000AAA',
#  'url': 'http://www.atcc.org/Products/All/HTB-22.aspx',
#  'aliases': ['richard-myers:MCF7-003'],
#  'schema_version': '26',
#  'status': 'released',
#  'lab': '/labs/richard-myers/',
#  'award': '/awards/U54HG004576/',
#  'date_created': '2013-12-12T05:50:02.101495+00:00',
#  'submitted_by': '/users/df9f3c8e-b819-4885-8f16-08f6ef0001e8/',
#  'notes': '(PMID: 4357757)',
#  'documents': ['/documents/984071d4-9149-476a-b353-93592c6f48f3/'],
#  'references': [],
#  'source': '/sources/atcc/',
#  'product_id': 'HTB-22',
#  'biosample_ontology': '/biosample-types/cell_line_EFO_0001203/',
#  'genetic_modifications': [],
#  'alternate_accessions': [],
#  'description': 'mammary gland, adenocarcinoma',
#  'treatments': [],
#  'dbxrefs': ['UCSC-ENCODE-cv:MCF-7'],
#  'donor': '/human-donors/ENCDO000AAE/',
#  'organism': '/organisms/human/',
#  'passage_number': 5,
#  'internal_tags': [],
#  'culture_harvest_date': '2012-04-10',
#  'culture_start_date': '2012-03-16',
#  '@id': '/biosamples/ENCBS000AAA/',
#  '@type': ['Biosample', 'Item'],
#  'uuid': '56e94f2b-25ac-4c58-9828-f63b66220999',
#  'sex': 'female',
#  'age': '69',
#  'age_units': 'year',
#  'health_status': 'breast cancer (adenocarcinoma)',
#  'life_stage': 'adult',
#  'applied_modifications': [],
#  'characterizations': [],
#  'parent_of': [],
#  'age_display': '69 years',
#  'origin_batch': '/biosamples/ENCBS000AAA/',
#  'perturbed': False,
#  'simple_summary': '',
#  'summary': 'Homo sapiens MCF-7 cell line'}

# %% [markdown]
# <b> Perform search for file on md5 code </b>

# %%
md5 = "7b9f8ccd15fea0bda867e042db2b6f5a"

# %%
database.search_file_on_md5(md5_code=md5)

# %%
database.md5_search.json()
# Out:
# {'@context': '/terms/',
#  '@graph': [{'@id': '/files/ENCFF000BXK/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF000BXK',
#    'assay_term_name': 'ChIP-seq',
#    'assembly': 'hg19',
#    'award': {'project': 'ENCODE'},
#    'biological_replicates': [1],
#    'biosample_ontology': {'organ_slims': ['bodily fluid', 'blood'],
#     'term_name': 'K562'},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2010-11-16T00:00:00.000000+00:00',
#    'derived_from': ['/files/ENCFF000BXX/'],
#    'file_format': 'bam',
#    'file_size': 964104660,
#    'file_type': 'bam',
#    'href': '/files/ENCFF000BXK/@@download/ENCFF000BXK.bam',
#    'lab': {'title': 'Bradley Bernstein, Broad'},
#    'mapped_read_length': 36,
#    'mapped_run_type': 'single-ended',
#    'origin_batches': ['/biosamples/ENCBS639AAA/'],
#    'output_category': 'alignment',
#    'output_type': 'alignments',
#    'quality_metrics': [],
#    'read_length_units': 'nt',
#    'simple_biosample_summary': '',
#    'status': 'archived',
#    'target': {'label': 'H3K4me1'},
#    'technical_replicates': ['1_1'],
#    'title': 'ENCFF000BXK'}],
#  '@id': '/search/?type=File&md5sum=7b9f8ccd15fea0bda867e042db2b6f5a&format=json',
#  '@type': ['Search'],
#  'clear_filters': '/search/?type=File',
#  'columns': {'@id': {'title': 'ID'},
#   'title': {'title': 'Title'},
#   'accession': {'title': 'Accession'},
#   'dataset': {'title': 'Dataset'},
#   'assembly': {'title': 'Genome assembly'},
#   'technical_replicates': {'title': 'Technical replicates'},
#   'biological_replicates': {'title': 'Biological replicates'},
#   'file_format': {'title': 'File Format'},
#   'file_type': {'title': 'File type'},
#   'file_format_type': {'title': 'File format type'},
#   'file_size': {'title': 'File size'},
#   'assay_term_name': {'title': 'Assay term name'},
#   'biosample_ontology.term_name': {'title': 'Biosample name'},
#   'biosample_ontology.organ_slims': {'title': 'Organ'},
#   'simple_biosample_summary': {'title': 'Simple biosample summary'},
#   'origin_batches': {'title': 'Batch'},
#   'target.label': {'title': 'Target label'},
#   'href': {'title': 'Download URL'},
#   'derived_from': {'title': 'Derived from'},
#   'genome_annotation': {'title': 'Genome annotation'},
#   'replicate.library.accession': {'title': 'Library'},
#   'paired_end': {'title': 'Paired end identifier'},
#   'paired_with': {'title': 'Paired with'},
#   'preferred_default': {'title': 'Preferred Default'},
#   'run_type': {'title': 'Run type'},
#   'read_length': {'title': 'Read length'},
#   'mapped_read_length': {'title': 'Mapped read length (nt)'},
#   'cropped_read_length': {'title': 'Cropped read length (nt)'},
#   'cropped_read_length_tolerance': {'title': 'Cropped read length tolerance (nt)'},
#   'mapped_run_type': {'title': 'Mapped run type for bam files'},
#   'read_length_units': {'title': 'Read length units'},
#   'output_category': {'title': 'Output category'},
#   'output_type': {'title': 'Output type'},
#   'index_of': {'title': 'Index of'},
#   'quality_metrics': {'title': 'QC Metric'},
#   'lab.title': {'title': 'Lab'},
#   'award.project': {'title': 'Project'},
#   'step_run': {'title': 'Analysis step run'},
#   'date_created': {'title': 'Date created'},
#   'analysis_step_version': {'title': 'Analysis step version'},
#   'restricted': {'title': 'Restricted file'},
#   'submitter_comment': {'title': 'Submitter comment'},
#   'status': {'title': 'Status'},
#   'annotation_type': {'title': 'Annotation type'},
#   'annotation_subtype': {'title': 'Annotation subtype'},
#   'biochemical_inputs': {'title': 'Biochemical activity'},
#   'encyclopedia_version': {'title': 'Encyclopedia version'}},
#  'facet_groups': [{'name': 'File',
#    'title': 'Format',
#    'facet_fields': ['output_category',
#     'output_type',
#     'file_format',
#     'file_format_type',
#     'file_type']},
#   {'name': 'File',
#    'title': 'Assay',
#    'facet_fields': ['assay_title',
#     'platform.term_name',
#     'target.label',
#     'targets.label']},
#   {'name': 'File',
#    'title': 'Annotation',
#    'facet_fields': ['annotation_type',
#     'annotation_subtype',
#     'encyclopedia_version']},
#   {'name': 'File',
#    'title': 'Biosample',
#    'facet_fields': ['biosample_ontology.term_name',
#     'biosample_ontology.organ_slims',
#     'origin_batches',
#     'biosample_ontology.cell_slims',
#     'biosample_ontology.system_slims']},
#   {'name': 'File', 'title': 'Analysis', 'facet_fields': ['assembly']},
#   {'name': 'File',
#    'title': 'Provenance',
#    'facet_fields': ['award.project', 'lab.title']},
#   {'name': 'File',
#    'title': 'Quality',
#    'facet_fields': ['status',
#     'audit.ERROR.category',
#     'audit.NOT_COMPLIANT.category',
#     'audit.WARNING.category',
#     'audit.INTERNAL_ACTION.category']}],
#  'facets': [{'field': 'type',
#    'title': 'Data Type',
#    'terms': [{'key': 'File', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'status',
#    'title': 'Status',
#    'terms': [{'key': 'archived', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': True},
#   {'field': 'output_category',
#    'title': 'Output category',
#    'terms': [{'key': 'alignment', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'output_type',
#    'title': 'Output type',
#    'terms': [{'key': 'alignments', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'file_format',
#    'title': 'File format',
#    'terms': [{'key': 'bam', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': True},
#   {'field': 'file_type',
#    'title': 'File type',
#    'terms': [{'key': 'bam', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'award.project',
#    'title': 'Project',
#    'terms': [{'key': 'ENCODE', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'assembly',
#    'title': 'Genome assembly',
#    'terms': [{'key': 'hg19', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'lab.title',
#    'title': 'Lab',
#    'terms': [{'key': 'Bradley Bernstein, Broad', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'assay_title',
#    'title': 'Assay title',
#    'terms': [{'key': 'Histone ChIP-seq', 'doc_count': 1}],
#    'total': 1,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.term_name',
#    'title': 'Biosample',
#    'terms': [{'key': 'K562', 'doc_count': 1}],
#    'total': 1,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.organ_slims',
#    'title': 'Organ',
#    'terms': [{'key': 'blood', 'doc_count': 1},
#     {'key': 'bodily fluid', 'doc_count': 1}],
#    'total': 1,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'origin_batches',
#    'title': 'Batch',
#    'terms': [{'key': '/biosamples/ENCBS639AAA/', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.cell_slims',
#    'title': 'Cell',
#    'terms': [{'key': 'cancer cell', 'doc_count': 1},
#     {'key': 'hematopoietic cell', 'doc_count': 1},
#     {'key': 'leukocyte', 'doc_count': 1}],
#    'total': 1,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.system_slims',
#    'title': 'Systems',
#    'terms': [{'key': 'immune system', 'doc_count': 1}],
#    'total': 1,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'target.label',
#    'title': 'Target of assay',
#    'terms': [{'key': 'H3K4me1', 'doc_count': 1}],
#    'total': 1,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'md5sum',
#    'title': 'md5sum',
#    'terms': [{'key': '7b9f8ccd15fea0bda867e042db2b6f5a', 'isEqual': True}],
#    'appended': True,
#    'total': 1}],
#  'filters': [{'field': 'md5sum',
#    'term': '7b9f8ccd15fea0bda867e042db2b6f5a',
#    'remove': '/search/?type=File&format=json'},
#   {'field': 'type',
#    'term': 'File',
#    'remove': '/search/?md5sum=7b9f8ccd15fea0bda867e042db2b6f5a&format=json'}],
#  'notification': 'Success',
#  'sort': {'date_created': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'label': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'uuid': {'order': 'desc', 'unmapped_type': 'keyword'}},
#  'title': 'Search',
#  'total': 1}

# %% [markdown]
# <b> Perform search on Experiment Accession Number</b>

# %%
code_for_experiment_search = "ENCSR000AKS"

# %%
database.search_on_experiment(experiment_code=code_for_experiment_search )

# %%
database.response_experiment.json()
# Out:
# {'@context': '/terms/',
#  '@graph': [{'@id': '/files/ENCFF534KXV/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF534KXV',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-5-glob-155eada107f68a2195912a39f5dee4bc-rep2_vs_rep3.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/f4b592e3-673a-4d44-be29-3154296baf3c/ENCFF534KXV.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'FtgosTT8qZiquGGgvqDbAQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/f4b592e3-673a-4d44-be29-3154296baf3c/ENCFF534KXV.bigBed',
#     'file_size': 3107725},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:08.592065+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF486QGD/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 3107725,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF534KXV/@@download/ENCFF534KXV.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': '16d828b134fca998aab861a0bea0db01',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/f4b592e3-673a-4d44-be29-3154296baf3c/ENCFF534KXV.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/f3544b56-bf56-416e-bbaa-b3ded832318a/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-5/glob-155eada107f68a2195912a39f5dee4bc/rep2_vs_rep3.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF534KXV',
#    'uuid': 'f4b592e3-673a-4d44-be29-3154296baf3c'},
#   {'@id': '/files/ENCFF539JEM/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF539JEM',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-2-glob-155eada107f68a2195912a39f5dee4bc-rep1_vs_rep3.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/4c2a334e-7a9e-4e24-af4e-6539add54ad4/ENCFF539JEM.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'qHMFzXqdJ0sd3CK9IYrypQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/4c2a334e-7a9e-4e24-af4e-6539add54ad4/ENCFF539JEM.bigBed',
#     'file_size': 3280231},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:07.479003+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF722LYP/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 3280231,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF539JEM/@@download/ENCFF539JEM.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': 'a87305cd7a9d274b1ddc22bd218af2a5',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/4c2a334e-7a9e-4e24-af4e-6539add54ad4/ENCFF539JEM.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/f3544b56-bf56-416e-bbaa-b3ded832318a/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-2/glob-155eada107f68a2195912a39f5dee4bc/rep1_vs_rep3.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF539JEM',
#    'uuid': '4c2a334e-7a9e-4e24-af4e-6539add54ad4'},
#   {'@id': '/files/ENCFF692DJW/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF692DJW',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-1-glob-155eada107f68a2195912a39f5dee4bc-rep1_vs_rep2.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/67182903-4238-4348-a3e6-1844de6b46e2/ENCFF692DJW.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'Pyz+IOEJ4wyRI7CEQCogqw==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/67182903-4238-4348-a3e6-1844de6b46e2/ENCFF692DJW.bigBed',
#     'file_size': 4676904},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:06.279030+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF135ZLM/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 4676904,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF692DJW/@@download/ENCFF692DJW.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': '3f2cfe20e109e30c9123b084402a20ab',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'preferred_default': True,
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/67182903-4238-4348-a3e6-1844de6b46e2/ENCFF692DJW.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/f3544b56-bf56-416e-bbaa-b3ded832318a/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-1/glob-155eada107f68a2195912a39f5dee4bc/rep1_vs_rep2.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF692DJW',
#    'uuid': '67182903-4238-4348-a3e6-1844de6b46e2'},
#   {'@id': '/files/ENCFF026IVB/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF026IVB',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap_ppr-glob-155eada107f68a2195912a39f5dee4bc-pooled-pr1_vs_pooled-pr2.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-pooled-pseudoreplicated-overlap-stable-peaks-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/7181cb2f-59d2-453b-8897-7ea828b221d8/ENCFF026IVB.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'KKeeAMDIJVU2FALNV2nMoQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/7181cb2f-59d2-453b-8897-7ea828b221d8/ENCFF026IVB.bigBed',
#     'file_size': 4537269},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:04.615895+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF617BGN/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 4537269,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF026IVB/@@download/ENCFF026IVB.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': '28a79e00c0c82555361402cd5769cca1',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'pseudoreplicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/7181cb2f-59d2-453b-8897-7ea828b221d8/ENCFF026IVB.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/3342853c-3142-4413-bf9b-d759abe3c39d/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap_ppr/glob-155eada107f68a2195912a39f5dee4bc/pooled-pr1_vs_pooled-pr2.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF026IVB',
#    'uuid': '7181cb2f-59d2-453b-8897-7ea828b221d8'},
#   {'@id': '/files/ENCFF382PUM/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF382PUM',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap_pr-shard-2-glob-155eada107f68a2195912a39f5dee4bc-rep3-pr1_vs_rep3-pr2.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-pseudoreplicated-overlap-stable-peaks-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/f11af8c4-a08a-4751-b1e0-a7aa0bec4b6a/ENCFF382PUM.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [3],
#    'biological_replicates_formatted': 'Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'TNMi/8DkMCLsuG45JoOxYQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/f11af8c4-a08a-4751-b1e0-a7aa0bec4b6a/ENCFF382PUM.bigBed',
#     'file_size': 1940597},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:03.018117+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF324RWP/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 1940597,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF382PUM/@@download/ENCFF382PUM.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': '4cd322ffc0e43022ecb86e392683b161',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS376AIO/'],
#    'output_category': 'annotation',
#    'output_type': 'pseudoreplicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/f11af8c4-a08a-4751-b1e0-a7aa0bec4b6a/ENCFF382PUM.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/c828ac6a-baed-4882-8b41-9c6c5b8bb19b/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap_pr/shard-2/glob-155eada107f68a2195912a39f5dee4bc/rep3-pr1_vs_rep3-pr2.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['3_1', '3_2'],
#    'title': 'ENCFF382PUM',
#    'uuid': 'f11af8c4-a08a-4751-b1e0-a7aa0bec4b6a'},
#   {'@id': '/files/ENCFF996AMF/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF996AMF',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap_pr-shard-1-glob-155eada107f68a2195912a39f5dee4bc-rep2-pr1_vs_rep2-pr2.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-pseudoreplicated-overlap-stable-peaks-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}],
#     'WARNING': [{'path': '/files/ENCFF996AMF/',
#       'level_name': 'WARNING',
#       'level': 40,
#       'name': 'audit_file',
#       'detail': 'The md5 sum of file {ENCFF996AMF|/files/ENCFF996AMF/} matches that of file(s) {ENCFF274EWV|/files/ENCFF274EWV/}.',
#       'category': 'matching md5 sums'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/69237641-eeb9-4449-9dfa-1dac5c5951c3/ENCFF996AMF.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [2],
#    'biological_replicates_formatted': 'Rep 2',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'Jkh1hSeKdkMA1pHpy0tsqw==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/69237641-eeb9-4449-9dfa-1dac5c5951c3/ENCFF996AMF.bigBed',
#     'file_size': 3689016},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:02.215884+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF553IZN/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 3689016,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF996AMF/@@download/ENCFF996AMF.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'matching_md5sum': ['/files/ENCFF274EWV/'],
#    'md5sum': '26487585278a764300d691e9cb4b6cab',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/'],
#    'output_category': 'annotation',
#    'output_type': 'pseudoreplicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/69237641-eeb9-4449-9dfa-1dac5c5951c3/ENCFF996AMF.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/c828ac6a-baed-4882-8b41-9c6c5b8bb19b/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap_pr/shard-1/glob-155eada107f68a2195912a39f5dee4bc/rep2-pr1_vs_rep2-pr2.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['2_1'],
#    'title': 'ENCFF996AMF',
#    'uuid': '69237641-eeb9-4449-9dfa-1dac5c5951c3'},
#   {'@id': '/files/ENCFF842SGN/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF842SGN',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap_pr-shard-0-glob-155eada107f68a2195912a39f5dee4bc-rep1-pr1_vs_rep1-pr2.overlap.bfilt.narrowPeak.bb'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-pseudoreplicated-overlap-stable-peaks-file-format-conversion-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}],
#     'WARNING': [{'path': '/files/ENCFF842SGN/',
#       'level_name': 'WARNING',
#       'level': 40,
#       'name': 'audit_file',
#       'detail': 'The md5 sum of file {ENCFF842SGN|/files/ENCFF842SGN/} matches that of file(s) {ENCFF356TDM|/files/ENCFF356TDM/}.',
#       'category': 'matching md5 sums'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/20/c24625a5-c601-47b0-831c-1963ba13c612/ENCFF842SGN.bigBed?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1],
#    'biological_replicates_formatted': 'Rep 1',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'H7hDG03350UcDFX23Pomtg==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/20/c24625a5-c601-47b0-831c-1963ba13c612/ENCFF842SGN.bigBed',
#     'file_size': 5720190},
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-20T02:53:01.418663+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF573AQP/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bigBed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 5720190,
#    'file_type': 'bigBed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF842SGN/@@download/ENCFF842SGN.bigBed',
#    'lab': '/labs/encode-processing-pipeline/',
#    'matching_md5sum': ['/files/ENCFF356TDM/'],
#    'md5sum': '1fb8431b4df7e7451c0c55f6dcfa26b6',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'pseudoreplicated peaks',
#    'processed': True,
#    'quality_metrics': [],
#    's3_uri': 's3://encode-public/2022/06/20/c24625a5-c601-47b0-831c-1963ba13c612/ENCFF842SGN.bigBed',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/c828ac6a-baed-4882-8b41-9c6c5b8bb19b/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap_pr/shard-0/glob-155eada107f68a2195912a39f5dee4bc/rep1-pr1_vs_rep1-pr2.overlap.bfilt.narrowPeak.bb',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1'],
#    'title': 'ENCFF842SGN',
#    'uuid': 'c24625a5-c601-47b0-831c-1963ba13c612'},
#   {'@id': '/files/ENCFF486QGD/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF486QGD',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-5-glob-2e6c87fc90e45fa5dbda88934d454cd3-rep2_vs_rep3.overlap.bfilt.narrowPeak.gz'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/16/26990d14-0706-4063-9c1a-1bc985c5f1bf/ENCFF486QGD.bed.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'nqImifN9ey+kzESyl6PpMQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/16/26990d14-0706-4063-9c1a-1bc985c5f1bf/ENCFF486QGD.bed.gz',
#     'file_size': 1473320},
#    'content_md5sum': '556b0d52196f777c99eea280156383ca',
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-16T20:08:37.776401+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF839DZV/',
#     '/files/ENCFF420ARY/',
#     '/files/ENCFF226FKB/',
#     '/files/ENCFF103WYN/',
#     '/files/ENCFF356LFX/',
#     '/files/ENCFF666YXZ/',
#     '/files/ENCFF625ZHC/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 1473320,
#    'file_type': 'bed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF486QGD/@@download/ENCFF486QGD.bed.gz',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': '9ea22689f37d7b2fa4cc44b297a3e931',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'processed': True,
#    'quality_metrics': ['/chip-replication-quality-metrics/1e3da888-fb42-4c83-b231-24bf483af867/',
#     '/chip-peak-enrichment-quality-metrics/3514d1dd-bf3a-43ce-b9d0-583428741324/'],
#    's3_uri': 's3://encode-public/2022/06/16/26990d14-0706-4063-9c1a-1bc985c5f1bf/ENCFF486QGD.bed.gz',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/9c5fe6e3-f67c-46cc-999c-938888412d04/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-5/glob-2e6c87fc90e45fa5dbda88934d454cd3/rep2_vs_rep3.overlap.bfilt.narrowPeak.gz',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF486QGD',
#    'uuid': '26990d14-0706-4063-9c1a-1bc985c5f1bf'},
#   {'@id': '/files/ENCFF722LYP/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF722LYP',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-2-glob-2e6c87fc90e45fa5dbda88934d454cd3-rep1_vs_rep3.overlap.bfilt.narrowPeak.gz'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/16/ecee0a45-fff5-4aff-b567-04b01530e591/ENCFF722LYP.bed.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'uBB3nKTK6YH8M2yviT/vag==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/16/ecee0a45-fff5-4aff-b567-04b01530e591/ENCFF722LYP.bed.gz',
#     'file_size': 1560050},
#    'content_md5sum': '28881a4baf791c9de98d9a51ab793c8a',
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-16T20:08:36.808876+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF839DZV/',
#     '/files/ENCFF420ARY/',
#     '/files/ENCFF226FKB/',
#     '/files/ENCFF103WYN/',
#     '/files/ENCFF356LFX/',
#     '/files/ENCFF666YXZ/',
#     '/files/ENCFF625ZHC/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 1560050,
#    'file_type': 'bed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF722LYP/@@download/ENCFF722LYP.bed.gz',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': 'b810779ca4cae981fc336caf893fef6a',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'processed': True,
#    'quality_metrics': ['/chip-peak-enrichment-quality-metrics/1a2e5fc5-f3ea-40f9-a5ea-7c9c2f200f10/',
#     '/chip-replication-quality-metrics/3725c9ee-b7ce-46af-976b-f46eb4cf34c8/'],
#    's3_uri': 's3://encode-public/2022/06/16/ecee0a45-fff5-4aff-b567-04b01530e591/ENCFF722LYP.bed.gz',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/9c5fe6e3-f67c-46cc-999c-938888412d04/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-2/glob-2e6c87fc90e45fa5dbda88934d454cd3/rep1_vs_rep3.overlap.bfilt.narrowPeak.gz',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF722LYP',
#    'uuid': 'ecee0a45-fff5-4aff-b567-04b01530e591'},
#   {'@id': '/files/ENCFF135ZLM/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF135ZLM',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap-shard-1-glob-2e6c87fc90e45fa5dbda88934d454cd3-rep1_vs_rep2.overlap.bfilt.narrowPeak.gz'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-replicated-overlap-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/16/073cb48c-8d87-421e-93ea-a75879ce049a/ENCFF135ZLM.bed.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1, 2, 3],
#    'biological_replicates_formatted': 'Rep 1, Rep 2, Rep 3',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'stsxF14IVqKyfAZNqOS7tA==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/16/073cb48c-8d87-421e-93ea-a75879ce049a/ENCFF135ZLM.bed.gz',
#     'file_size': 2342260},
#    'content_md5sum': '8e61f8c212dfa03ef5920273a6bf20da',
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-16T20:08:35.739754+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF839DZV/',
#     '/files/ENCFF420ARY/',
#     '/files/ENCFF226FKB/',
#     '/files/ENCFF103WYN/',
#     '/files/ENCFF356LFX/',
#     '/files/ENCFF666YXZ/',
#     '/files/ENCFF625ZHC/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bed',
#    'file_format_type': 'narrowPeak',
#    'file_size': 2342260,
#    'file_type': 'bed narrowPeak',
#    'flowcell_details': [],
#    'href': '/files/ENCFF135ZLM/@@download/ENCFF135ZLM.bed.gz',
#    'lab': '/labs/encode-processing-pipeline/',
#    'md5sum': 'b2db31175e0856a2b27c064da8e4bbb4',
#    'no_file_available': False,
#    'origin_batches': ['/biosamples/ENCBS674MPN/',
#     '/biosamples/ENCBS376AIO/',
#     '/biosamples/ENCBS639AAA/'],
#    'output_category': 'annotation',
#    'output_type': 'replicated peaks',
#    'preferred_default': True,
#    'processed': True,
#    'quality_metrics': ['/chip-peak-enrichment-quality-metrics/28cbaf88-c405-4e7a-beb8-c19c2a2d109b/',
#     '/chip-replication-quality-metrics/ca9f7e83-0f5d-414a-a031-73c024721eb5/'],
#    's3_uri': 's3://encode-public/2022/06/16/073cb48c-8d87-421e-93ea-a75879ce049a/ENCFF135ZLM.bed.gz',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/9c5fe6e3-f67c-46cc-999c-938888412d04/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-overlap/shard-1/glob-2e6c87fc90e45fa5dbda88934d454cd3/rep1_vs_rep2.overlap.bfilt.narrowPeak.gz',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1', '2_1', '3_1', '3_2'],
#    'title': 'ENCFF135ZLM',
#    'uuid': '073cb48c-8d87-421e-93ea-a75879ce049a'},
#   {'@id': '/files/ENCFF617BGN/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF617BGN',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-overlap_ppr-glob-2e6c87fc90e45fa5dbda88934d454cd3-pooled-pr1_vs_pooled-pr2.overlap.bfilt.narrowPeak.gz'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/histone-chip-seq-pooled-pseudoreplicated-overlap-step-v-1-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
# ...
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-filter/shard-1/glob-3bcbe4e7489c90f75e0523ac6f3a9385/ENCFF000BYG.crop_36-2bp.srt.nodup.bam',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['2_1'],
#    'title': 'ENCFF103WYN',
#    'uuid': '1d01bbca-f2f0-4b9d-ac42-8f4298cad37b'},
#   {'@id': '/files/ENCFF839DZV/',
#    '@type': ['File', 'Item'],
#    'accession': 'ENCFF839DZV',
#    'aliases': ['encode-processing-pipeline:39f88113-ace9-4d9e-806b-33f0171bf328-encode-processing-caper_out_v04_05-chip-39f88113-ace9-4d9e-806b-33f0171bf328-call-filter-shard-0-glob-3bcbe4e7489c90f75e0523ac6f3a9385-ENCFF000BXX.crop_36-2bp.srt.nodup.bam'],
#    'alternate_accessions': [],
#    'analyses': ['/analyses/ENCAN211AVB/'],
#    'analysis_step_version': '/analysis-step-versions/chip-seq-alignment-step-v-2-0/',
#    'assay_term_name': 'ChIP-seq',
#    'assay_title': 'Histone ChIP-seq',
#    'assembly': 'GRCh38',
#    'audit': {'INTERNAL_ACTION': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'INTERNAL_ACTION',
#       'level': 30,
#       'name': 'audit_item_status',
#       'detail': 'Released analysis {ENCAN211AVB|/analyses/ENCAN211AVB/} has in progress subobject quality standard {encode4-histone-chip|/quality-standards/encode4-histone-chip/}',
#       'category': 'mismatched status'}],
#     'NOT_COMPLIANT': [{'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF839DZV|/files/ENCFF839DZV/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 9397237 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'},
#      {'path': '/analyses/ENCAN211AVB/',
#       'level_name': 'NOT_COMPLIANT',
#       'level': 50,
#       'name': 'audit_analysis',
#       'detail': 'Processed alignments file {ENCFF103WYN|/files/ENCFF103WYN/} processed by ChIP-seq ENCODE4 v1.8.0 GRCh38 pipeline has 8138614 usable fragments. The minimum ENCODE standard for each replicate in a ChIP-seq experiment targeting H3K4me1-human and investigated as a broad histone mark is 20 million usable fragments. The recommended value is > 45 million, but > 35 million is acceptable. (See {ENCODE ChIP-seq data standards|/data-standards/chip-seq/})',
#       'category': 'insufficient read depth'}],
#     'WARNING': [{'path': '/files/ENCFF839DZV/',
#       'level_name': 'WARNING',
#       'level': 40,
#       'name': 'audit_file',
#       'detail': 'The md5 sum of file {ENCFF839DZV|/files/ENCFF839DZV/} matches that of file(s) {ENCFF352HXD|/files/ENCFF352HXD/}.',
#       'category': 'matching md5 sums'}]},
#    'award': '/awards/U24HG009397/',
#    'azure_uri': 'https://datasetencode.blob.core.windows.net/dataset/2022/06/14/d8933c42-6ba7-4893-a359-538745952ba4/ENCFF839DZV.bam?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D',
#    'biological_replicates': [1],
#    'biological_replicates_formatted': 'Rep 1',
#    'biosample_ontology': '/biosample-types/cell_line_EFO_0002067/',
#    'cloud_metadata': {'md5sum_base64': 'lU70PzS9hmvxLt1CdKTkCQ==',
#     'url': 'https://encode-public.s3.amazonaws.com/2022/06/14/d8933c42-6ba7-4893-a359-538745952ba4/ENCFF839DZV.bam',
#     'file_size': 517904299},
#    'content_md5sum': 'cbb4e3c2d4321c0e09287eabf0f4a257',
#    'cropped_read_length': 36,
#    'cropped_read_length_tolerance': 2,
#    'dataset': '/experiments/ENCSR000AKS/',
#    'date_created': '2022-06-14T16:55:11.419954+00:00',
#    'dbxrefs': [],
#    'derived_from': ['/files/ENCFF000BXX/', '/files/ENCFF110MCL/'],
#    'donors': ['/human-donors/ENCDO000AAD/'],
#    'fastq_signature': [],
#    'file_format': 'bam',
#    'file_size': 517904299,
#    'file_type': 'bam',
#    'flowcell_details': [],
#    'href': '/files/ENCFF839DZV/@@download/ENCFF839DZV.bam',
#    'lab': '/labs/encode-processing-pipeline/',
#    'mapped_read_length': 36,
#    'mapped_run_type': 'single-ended',
#    'matching_md5sum': ['/files/ENCFF352HXD/'],
#    'md5sum': '954ef43f34bd866bf12edd4274a4e409',
#    'no_file_available': False,
#    'notes': 'File content md5sum conflicts with content md5sum of existing file(s) cbb4e3c2d4321c0e09287eabf0f4a257 in file ENCFF352HXD',
#    'origin_batches': ['/biosamples/ENCBS639AAA/'],
#    'output_category': 'alignment',
#    'output_type': 'alignments',
#    'processed': True,
#    'quality_metrics': ['/chip-alignment-enrichment-quality-metrics/31b81563-2e5d-43d4-bd4f-6cc29f435ef5/',
#     '/chip-alignment-quality-metrics/beccdd66-020b-459e-a60c-48099fee8f61/',
#     '/chip-library-quality-metrics/711e7d40-f703-44d6-afd6-b0a49d8d949b/'],
#    'read_length_units': 'nt',
#    's3_uri': 's3://encode-public/2022/06/14/d8933c42-6ba7-4893-a359-538745952ba4/ENCFF839DZV.bam',
#    'schema_version': '29',
#    'simple_biosample_summary': '',
#    'status': 'released',
#    'step_run': '/analysis-step-runs/f4e34b64-cba2-4f68-a2e5-8c85149f0f30/',
#    'submitted_by': '/users/6bae687f-b77a-46b9-af0e-a02c135cf42e/',
#    'submitted_file_name': 'gs://encode-processing/caper_out_v04_05/chip/39f88113-ace9-4d9e-806b-33f0171bf328/call-filter/shard-0/glob-3bcbe4e7489c90f75e0523ac6f3a9385/ENCFF000BXX.crop_36-2bp.srt.nodup.bam',
#    'superseded_by': [],
#    'target': '/targets/H3K4me1-human/',
#    'technical_replicates': ['1_1'],
#    'title': 'ENCFF839DZV',
#    'uuid': 'd8933c42-6ba7-4893-a359-538745952ba4'}],
#  '@id': '/search/?type=File&dataset=/experiments/ENCSR000AKS/&format=json&frame=object',
#  '@type': ['Search'],
#  'all': '/search/?type=File&dataset=%2Fexperiments%2FENCSR000AKS%2F&format=json&frame=object&limit=all',
#  'clear_filters': '/search/?type=File',
#  'columns': {'@id': {'title': 'ID'},
#   'title': {'title': 'Title'},
#   'accession': {'title': 'Accession'},
#   'dataset': {'title': 'Dataset'},
#   'assembly': {'title': 'Genome assembly'},
#   'technical_replicates': {'title': 'Technical replicates'},
#   'biological_replicates': {'title': 'Biological replicates'},
#   'file_format': {'title': 'File Format'},
#   'file_type': {'title': 'File type'},
#   'file_format_type': {'title': 'File format type'},
#   'file_size': {'title': 'File size'},
#   'assay_term_name': {'title': 'Assay term name'},
#   'biosample_ontology.term_name': {'title': 'Biosample name'},
#   'biosample_ontology.organ_slims': {'title': 'Organ'},
#   'simple_biosample_summary': {'title': 'Simple biosample summary'},
#   'origin_batches': {'title': 'Batch'},
#   'target.label': {'title': 'Target label'},
#   'href': {'title': 'Download URL'},
#   'derived_from': {'title': 'Derived from'},
#   'genome_annotation': {'title': 'Genome annotation'},
#   'replicate.library.accession': {'title': 'Library'},
#   'paired_end': {'title': 'Paired end identifier'},
#   'paired_with': {'title': 'Paired with'},
#   'preferred_default': {'title': 'Preferred Default'},
#   'run_type': {'title': 'Run type'},
#   'read_length': {'title': 'Read length'},
#   'mapped_read_length': {'title': 'Mapped read length (nt)'},
#   'cropped_read_length': {'title': 'Cropped read length (nt)'},
#   'cropped_read_length_tolerance': {'title': 'Cropped read length tolerance (nt)'},
#   'mapped_run_type': {'title': 'Mapped run type for bam files'},
#   'read_length_units': {'title': 'Read length units'},
#   'output_category': {'title': 'Output category'},
#   'output_type': {'title': 'Output type'},
#   'index_of': {'title': 'Index of'},
#   'quality_metrics': {'title': 'QC Metric'},
#   'lab.title': {'title': 'Lab'},
#   'award.project': {'title': 'Project'},
#   'step_run': {'title': 'Analysis step run'},
#   'date_created': {'title': 'Date created'},
#   'analysis_step_version': {'title': 'Analysis step version'},
#   'restricted': {'title': 'Restricted file'},
#   'submitter_comment': {'title': 'Submitter comment'},
#   'status': {'title': 'Status'},
#   'annotation_type': {'title': 'Annotation type'},
#   'annotation_subtype': {'title': 'Annotation subtype'},
#   'biochemical_inputs': {'title': 'Biochemical activity'},
#   'encyclopedia_version': {'title': 'Encyclopedia version'}},
#  'facet_groups': [{'name': 'File',
#    'title': 'Format',
#    'facet_fields': ['output_category',
#     'output_type',
#     'file_format',
#     'file_format_type',
#     'file_type']},
#   {'name': 'File',
#    'title': 'Assay',
#    'facet_fields': ['assay_title',
#     'platform.term_name',
#     'target.label',
#     'targets.label']},
#   {'name': 'File',
#    'title': 'Annotation',
#    'facet_fields': ['annotation_type',
#     'annotation_subtype',
#     'encyclopedia_version']},
#   {'name': 'File',
#    'title': 'Biosample',
#    'facet_fields': ['biosample_ontology.term_name',
#     'biosample_ontology.organ_slims',
#     'origin_batches',
#     'biosample_ontology.cell_slims',
#     'biosample_ontology.system_slims']},
#   {'name': 'File', 'title': 'Analysis', 'facet_fields': ['assembly']},
#   {'name': 'File',
#    'title': 'Provenance',
#    'facet_fields': ['award.project', 'lab.title']},
#   {'name': 'File',
#    'title': 'Quality',
#    'facet_fields': ['status',
#     'audit.ERROR.category',
#     'audit.NOT_COMPLIANT.category',
#     'audit.WARNING.category',
#     'audit.INTERNAL_ACTION.category']}],
#  'facets': [{'field': 'type',
#    'title': 'Data Type',
#    'terms': [{'key': 'File', 'doc_count': 82}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'status',
#    'title': 'Status',
#    'terms': [{'key': 'released', 'doc_count': 74},
#     {'key': 'archived', 'doc_count': 8}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': True},
#   {'field': 'output_category',
#    'title': 'Output category',
#    'terms': [{'key': 'annotation', 'doc_count': 32},
#     {'key': 'signal', 'doc_count': 23},
#     {'key': 'alignment', 'doc_count': 21},
#     {'key': 'raw data', 'doc_count': 6}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'output_type',
#    'title': 'Output type',
#    'terms': [{'key': 'pseudoreplicated peaks', 'doc_count': 14},
#     {'key': 'alignments', 'doc_count': 12},
#     {'key': 'fold change over control', 'doc_count': 11},
#     {'key': 'signal p-value', 'doc_count': 11},
#     {'key': 'replicated peaks', 'doc_count': 10},
#     {'key': 'unfiltered alignments', 'doc_count': 9},
#     {'key': 'peaks', 'doc_count': 8},
#     {'key': 'reads', 'doc_count': 6},
#     {'key': 'signal', 'doc_count': 1}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'file_format',
#    'title': 'File format',
#    'terms': [{'key': 'bigWig', 'doc_count': 23},
#     {'key': 'bam', 'doc_count': 20},
#     {'key': 'bed', 'doc_count': 16},
#     {'key': 'bigBed', 'doc_count': 16},
#     {'key': 'fastq', 'doc_count': 6},
#     {'key': 'tagAlign', 'doc_count': 1}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': True},
#   {'field': 'file_format_type',
#    'title': 'File format type',
#    'terms': [{'key': 'narrowPeak', 'doc_count': 30},
#     {'key': 'broadPeak', 'doc_count': 2}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'file_type',
#    'title': 'File type',
#    'terms': [{'key': 'bigWig', 'doc_count': 23},
#     {'key': 'bam', 'doc_count': 20},
#     {'key': 'bed narrowPeak', 'doc_count': 15},
#     {'key': 'bigBed narrowPeak', 'doc_count': 15},
#     {'key': 'fastq', 'doc_count': 6},
#     {'key': 'bed broadPeak', 'doc_count': 1},
#     {'key': 'bigBed broadPeak', 'doc_count': 1},
#     {'key': 'tagAlign', 'doc_count': 1}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'platform.term_name',
#    'title': 'Platform',
#    'terms': [{'key': 'Illumina HiSeq 2500', 'doc_count': 4},
#     {'key': 'Illumina Genome Analyzer IIe', 'doc_count': 1},
#     {'key': 'Illumina Genome Analyzer IIx', 'doc_count': 1}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'award.project',
#    'title': 'Project',
#    'terms': [{'key': 'ENCODE', 'doc_count': 79},
#     {'key': 'Roadmap', 'doc_count': 3}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'assembly',
#    'title': 'Genome assembly',
#    'terms': [{'key': 'GRCh38', 'doc_count': 50},
#     {'key': 'hg19', 'doc_count': 26}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'lab.title',
#    'title': 'Lab',
#    'terms': [{'key': 'ENCODE Processing Pipeline', 'doc_count': 68},
#     {'key': 'Bradley Bernstein, Broad', 'doc_count': 11},
#     {'key': 'Anshul Kundaje, Stanford', 'doc_count': 3}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'assay_title',
#    'title': 'Assay title',
#    'terms': [{'key': 'Histone ChIP-seq', 'doc_count': 82}],
#    'total': 82,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.term_name',
#    'title': 'Biosample',
#    'terms': [{'key': 'K562', 'doc_count': 82}],
#    'total': 82,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.organ_slims',
#    'title': 'Organ',
#    'terms': [{'key': 'blood', 'doc_count': 82},
#     {'key': 'bodily fluid', 'doc_count': 82}],
#    'total': 82,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'origin_batches',
#    'title': 'Batch',
#    'terms': [{'key': '/biosamples/ENCBS639AAA/', 'doc_count': 44},
#     {'key': '/biosamples/ENCBS674MPN/', 'doc_count': 44},
#     {'key': '/biosamples/ENCBS376AIO/', 'doc_count': 20}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.cell_slims',
#    'title': 'Cell',
#    'terms': [{'key': 'cancer cell', 'doc_count': 82},
#     {'key': 'hematopoietic cell', 'doc_count': 82},
#     {'key': 'leukocyte', 'doc_count': 82}],
#    'total': 82,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'biosample_ontology.system_slims',
#    'title': 'Systems',
#    'terms': [{'key': 'immune system', 'doc_count': 82}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'target.label',
#    'title': 'Target of assay',
#    'terms': [{'key': 'H3K4me1', 'doc_count': 82}],
#    'total': 82,
#    'type': 'typeahead',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'audit.NOT_COMPLIANT.category',
#    'title': 'Audit category: NOT COMPLIANT',
#    'terms': [{'key': 'insufficient read depth', 'doc_count': 68},
#     {'key': 'control insufficient read depth', 'doc_count': 6}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'audit.WARNING.category',
#    'title': 'Audit category: WARNING',
#    'terms': [{'key': 'matching md5 sums', 'doc_count': 20},
#     {'key': 'inconsistent platforms', 'doc_count': 6},
#     {'key': 'low read length', 'doc_count': 6},
#     {'key': 'mixed read lengths', 'doc_count': 6},
#     {'key': 'missing controlled_by', 'doc_count': 4},
#     {'key': 'inconsistent control read length', 'doc_count': 1}],
#    'total': 82,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'dataset',
#    'title': 'dataset',
#    'terms': [{'key': '/experiments/ENCSR000AKS/', 'isEqual': True}],
#    'appended': True,
#    'total': 25}],
#  'filters': [{'field': 'dataset',
#    'term': '/experiments/ENCSR000AKS/',
#    'remove': '/search/?type=File&format=json&frame=object'},
#   {'field': 'type',
#    'term': 'File',
#    'remove': '/search/?dataset=%2Fexperiments%2FENCSR000AKS%2F&format=json&frame=object'}],
#  'notification': 'Success',
#  'sort': {'date_created': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'label': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'uuid': {'order': 'desc', 'unmapped_type': 'keyword'}},
#  'title': 'Search',
#  'total': 82}

# %% [markdown]
# <b> Search all replicates for one experiment </b>

# %%
code_for_replicate_search="ENCSR000AKS"

# %%
database.search_all_replicates_for_experiment(experiment_code=code_for_replicate_search)

# %%
database.response_replicates.json()
# Out:
# {'@context': '/terms/',
#  '@graph': [{'@id': '/replicates/cf59360f-f46d-4cd4-91d6-f02343e3a660/',
#    '@type': ['Replicate', 'Item'],
#    'aliases': ['bradley-bernstein:Rep_DNA_Lib 8051']},
#   {'@id': '/replicates/9b51f350-7070-48ae-9534-266b449885f8/',
#    '@type': ['Replicate', 'Item'],
#    'aliases': ['bradley-bernstein:Rep_DNA_Lib 8049']},
#   {'@id': '/replicates/cb79831f-7786-4bcf-b881-f42740d82727/',
#    '@type': ['Replicate', 'Item'],
#    'aliases': []},
#   {'@id': '/replicates/8adabf24-52c4-482c-a3a0-3a47e4b59af8/',
#    '@type': ['Replicate', 'Item'],
#    'aliases': []}],
#  '@id': '/search/?type=Replicate&experiment.accession=ENCSR000AKS&format=json',
#  '@type': ['Search'],
#  'clear_filters': '/search/?type=Replicate',
#  'columns': {'@id': {'title': 'ID'}, 'aliases': {'title': 'Aliases'}},
#  'facet_groups': [],
#  'facets': [{'field': 'type',
#    'title': 'Data Type',
#    'terms': [{'key': 'Replicate', 'doc_count': 4}],
#    'total': 4,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'status',
#    'title': 'Status',
#    'terms': [{'key': 'released', 'doc_count': 4}],
#    'total': 4,
#    'type': 'terms',
#    'appended': False,
#    'open_on_load': False},
#   {'field': 'experiment.accession',
#    'title': 'experiment.accession',
#    'terms': [{'key': 'ENCSR000AKS', 'isEqual': True}],
#    'appended': True,
#    'total': 4}],
#  'filters': [{'field': 'experiment.accession',
#    'term': 'ENCSR000AKS',
#    'remove': '/search/?type=Replicate&format=json'},
#   {'field': 'type',
#    'term': 'Replicate',
#    'remove': '/search/?experiment.accession=ENCSR000AKS&format=json'}],
#  'notification': 'Success',
#  'sort': {'date_created': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'label': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'uuid': {'order': 'desc', 'unmapped_type': 'keyword'}},
#  'title': 'Search',
#  'total': 4}

# %% [markdown]
# <b> Search the fastq files belonging to an experiment </b>

# %%
code_to_search_fastq_files = "ENCSR000AKS"

# %%
database.search_fastq_files_experiment(experiment_code=code_to_search_fastq_files)

# %%
database.response_fastq_search.json()
# Out:
# {'@context': '/terms/',
#  '@graph': [],
#  '@id': '/search/?type=File&dataset=/experiments/ENCSR000AKS+/&file_format=fastq&format=json&frame=object',
#  '@type': ['Search'],
#  'clear_filters': '/search/?type=File',
#  'columns': {'@id': {'title': 'ID'},
#   'title': {'title': 'Title'},
#   'accession': {'title': 'Accession'},
#   'dataset': {'title': 'Dataset'},
#   'assembly': {'title': 'Genome assembly'},
#   'technical_replicates': {'title': 'Technical replicates'},
#   'biological_replicates': {'title': 'Biological replicates'},
#   'file_format': {'title': 'File Format'},
#   'file_type': {'title': 'File type'},
#   'file_format_type': {'title': 'File format type'},
#   'file_size': {'title': 'File size'},
#   'assay_term_name': {'title': 'Assay term name'},
#   'biosample_ontology.term_name': {'title': 'Biosample name'},
#   'biosample_ontology.organ_slims': {'title': 'Organ'},
#   'simple_biosample_summary': {'title': 'Simple biosample summary'},
#   'origin_batches': {'title': 'Batch'},
#   'target.label': {'title': 'Target label'},
#   'href': {'title': 'Download URL'},
#   'derived_from': {'title': 'Derived from'},
#   'genome_annotation': {'title': 'Genome annotation'},
#   'replicate.library.accession': {'title': 'Library'},
#   'paired_end': {'title': 'Paired end identifier'},
#   'paired_with': {'title': 'Paired with'},
#   'preferred_default': {'title': 'Preferred Default'},
#   'run_type': {'title': 'Run type'},
#   'read_length': {'title': 'Read length'},
#   'mapped_read_length': {'title': 'Mapped read length (nt)'},
#   'cropped_read_length': {'title': 'Cropped read length (nt)'},
#   'cropped_read_length_tolerance': {'title': 'Cropped read length tolerance (nt)'},
#   'mapped_run_type': {'title': 'Mapped run type for bam files'},
#   'read_length_units': {'title': 'Read length units'},
#   'output_category': {'title': 'Output category'},
#   'output_type': {'title': 'Output type'},
#   'index_of': {'title': 'Index of'},
#   'quality_metrics': {'title': 'QC Metric'},
#   'lab.title': {'title': 'Lab'},
#   'award.project': {'title': 'Project'},
#   'step_run': {'title': 'Analysis step run'},
#   'date_created': {'title': 'Date created'},
#   'analysis_step_version': {'title': 'Analysis step version'},
#   'restricted': {'title': 'Restricted file'},
#   'submitter_comment': {'title': 'Submitter comment'},
#   'status': {'title': 'Status'},
#   'annotation_type': {'title': 'Annotation type'},
#   'annotation_subtype': {'title': 'Annotation subtype'},
#   'biochemical_inputs': {'title': 'Biochemical activity'},
#   'encyclopedia_version': {'title': 'Encyclopedia version'}},
#  'facet_groups': [{'name': 'File',
#    'title': 'Format',
#    'facet_fields': ['output_category',
#     'output_type',
#     'file_format',
#     'file_format_type',
#     'file_type']},
#   {'name': 'File',
#    'title': 'Assay',
#    'facet_fields': ['assay_title',
#     'platform.term_name',
#     'target.label',
#     'targets.label']},
#   {'name': 'File',
#    'title': 'Annotation',
#    'facet_fields': ['annotation_type',
#     'annotation_subtype',
#     'encyclopedia_version']},
#   {'name': 'File',
#    'title': 'Biosample',
#    'facet_fields': ['biosample_ontology.term_name',
#     'biosample_ontology.organ_slims',
#     'origin_batches',
#     'biosample_ontology.cell_slims',
#     'biosample_ontology.system_slims']},
#   {'name': 'File', 'title': 'Analysis', 'facet_fields': ['assembly']},
#   {'name': 'File',
#    'title': 'Provenance',
#    'facet_fields': ['award.project', 'lab.title']},
#   {'name': 'File',
#    'title': 'Quality',
#    'facet_fields': ['status',
#     'audit.ERROR.category',
#     'audit.NOT_COMPLIANT.category',
#     'audit.WARNING.category',
#     'audit.INTERNAL_ACTION.category']}],
#  'facets': [{'field': 'dataset',
#    'title': 'dataset',
#    'terms': [{'key': '/experiments/ENCSR000AKS /', 'isEqual': True}],
#    'appended': True,
#    'total': 0}],
#  'filters': [{'field': 'dataset',
#    'term': '/experiments/ENCSR000AKS /',
#    'remove': '/search/?type=File&file_format=fastq&format=json&frame=object'},
#   {'field': 'file_format',
#    'term': 'fastq',
#    'remove': '/search/?type=File&dataset=%2Fexperiments%2FENCSR000AKS+%2F&format=json&frame=object'},
#   {'field': 'type',
#    'term': 'File',
#    'remove': '/search/?dataset=%2Fexperiments%2FENCSR000AKS+%2F&file_format=fastq&format=json&frame=object'}],
#  'notification': 'No results found',
#  'sort': {'date_created': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'label': {'order': 'desc', 'unmapped_type': 'keyword'},
#   'uuid': {'order': 'desc', 'unmapped_type': 'keyword'}},
#  'title': 'Search',
#  'total': 0}
